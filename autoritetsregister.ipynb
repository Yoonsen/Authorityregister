# %%
import requests 
from bs4 import BeautifulSoup
import sys
import re

base_URL = "https://authority.bibsys.no/authority/rest"


def get_authority(identifier):
    res = requests.get( f"{base_URL}/authorities/v2/{identifier}")
    result = ""
    if res.status_code == 200:
        result = res.json()
    gender = ''
    life = ''
    name = ''
    for x in result['marcdata']:
        if '375' == x['tag']:
            if 'subfields' in x:
                sub = x['subfields']
                for s in sub:
                    if 'subcode' in s and 'value' in s:
                        if s['subcode'] == 'a':
                            gender = s['value']
        if '100' == x['tag']:
            if 'subfields' in x:
                sub = x['subfields']
                (b,d) = ('','')
                for s in sub:
                    if 'subcode' in s and 'value' in s:
                        if s['subcode'] == 'a':
                            name = s['value']
                        if s['subcode'] == 'd':
                            life = s['value']
                            x = life.split('-')
                            if len(x) == 2:
                                (b,d) = x    
    returnvalue = (name, gender, b,d, identifier)
    return returnvalue

def get_author(name, category = "person"):
    res = requests.get(f"https://api.nb.no/catalog/v1/authority/authorityid?size=20&authorityName={name}")
    if res.status_code != 200:
        return {}
    result = res.json()
    returnvalue = []
    for entry in result['content']:
        is_cat = entry['category'] == category
        has_id = entry['id'].startswith('bibsys')
        #is_quality = entry['qualityLevel'] == 'kat3' or entry['qualityLevel'] == 'kat2'
        if is_cat and has_id :
            entrycode = {
                "authorityid": entry['id'].split(':')[-1],
                "name": entry["primaryName"]
            }
            returnvalue.append(entrycode)
    if returnvalue != []:
        returnvalue = returnvalue[0]
    else:
        returnvalue = {}
    return returnvalue
    
def author_info(person):
    x = get_author(person)
    result = ()
    if 'authorityid' in x:
        result = get_authority(x['authorityid'])
    return result

def author_gender(person):
    """ 
        Find five of the records matching input parameter person.
        Return value is a 3-tuple with name in standard format, gender and life-span.
        Only returns a value if the characters in person is a subset of the characters in a name found in bibsys.
        assumes
            import requests 
            from bs4 import BeautifulSoup
            import sys
            import re
        input
            person a string
        output
            (name string, gender char, birth-death as string)
        
    """
    # remove punctuation characters - appears to be a problem for bibsys or ...
    person = re.sub('[^(\w|\s)]','', person)

    #print(person)
    
    # set up request parameter string

    req = "https://authority.bibsys.no/authority/rest/sru?operation=searchRetrieve&query={author}&startRecord=1&maximumRecords=50&recordPacking=xml&recordSchema=marcxchange" 
    
    # res is the return value, will contain a list of tuples if anything.
    res = []

    # issue request
    r = requests.get(req.format(author = person))

    
    # if everything is ok, go ahead and pick out the information
    if r.status_code == 200:
        # extract character symbols from person, used below to compare
        person_char = set(person.lower())
        #print(person_char)
        
        soup = BeautifulSoup(r.text, 'lxml')

        # name recides in tag 100, gender in tag 375
        # loop through all query matches
        for n in soup.find_all("srw:recorddata"):
            print(n, n.text)
            # initialise the components of the return tuple
            name = ""
            year = ""
            gender = ""
            
            # then try to extract som useful information
            namedata = n.find("marc:datafield",{'tag':100})
            if not namedata is None: 
                name_n = namedata.find("marc:subfield", {'code':'a'})
                if not name_n is None:
                    name = name_n.text
                year_n = namedata.find("marc:subfield", {'code':'d'})
                if not year_n is None:
                    year = year_n.text

            genderdata = n.find("marc:datafield", {'tag':375})
            if not genderdata is None:
                gender_n = genderdata.find("marc:subfield", {'code':'a'})
                if not gender_n is None:
                    gender = gender_n.text

            # Pseudonyms and other names for person related to query can get returned - retain only those 
            # that match the query here implemented as a subset relation. 
            # Bibsys will not match ó to o for example. If it does, this has to be replace by
            # some form of jaccard formula.

            #if person_char.issubset(set(name.lower())):
            res.append((name, gender, year))
            
    return res


#if __name__ == "__main__":
#    author_gender(' '.join(x for x in sys.argv))

# %%
import sqlite3
import pandas as pd

# %%
def query(sql, params = ()):
    with sqlite3.connect("/mnt/disk1/metadata.db") as con:
        cur = con.cursor()
        cur.execute(sql, params)
    return cur

# %%
def dbquery(db, sql, params = ()):
    with sqlite3.connect(db) as con:
        cur = con.cursor()
        cur.execute(sql, params)
    return cur.fetchall()

# %%
cur = query("select authors from metadata where doctype = 'digibok'")

# %%
names = set()
for x in cur:
    for n in [y.strip() for y in x[0].split('/')]:
        names |= {n}

# %%
len(names)
# Out:
# 192190

# %%
with open('namex.txt', "w") as f:
    for x in names:
        f.write(f"{x}\n")

# %%
with open('namex.txt') as f:
    names = f.read().split("\n")

# %%
author_info("anne ragde")
# Out:
# ('Ragde, Anne B.', 'f', '1957', '', '90097114')

# %%
import time

# %%
x = time.time()

# %%
round((time.time() - x)/60,2)
# Out:
# 0.01

# %%
dbquery("names_life_gender.db", "create table names (name, gender, born, dead, identifier)")
# Out:
# []

# %%
start_time = time.time()
with sqlite3.connect("names_life_gender.db") as con:
    cur = con.cursor()
    for i,x in enumerate(names):
        try:
            nom = author_info(x)
            #print(nom)
            cur.execute("insert into names values (?,?,?,?,?)", nom)
        except KeyboardInterrupt:
            break
        except:
            print(f" {i} feil ved {round((time.time() - start_time)/60,2)} minutter for {x}")
        if i % 10000 == 0:
            print(f"{i} logg ved {round((time.time() - start_time)/60,2)} minutter for {nom}")
# Out:
#  0 feil ved 0.0 minutter for
# 0 logg ved 0.0 minutter for ()
#  488 feil ved 1.09 minutter for Жадан , Сергiй Вiкторович
#  767 feil ved 1.72 minutter for Ræder , A[nton]
#  1689 feil ved 4.8 minutter for Norges tekniske høgskole
#  1791 feil ved 5.04 minutter for Løvberg , [Alf]
#  2175 feil ved 5.91 minutter for Dahl , Kjell-P[etter]
#  3946 feil ved 13.95 minutter for Ebbel]l] , Clara Thue
#  4000 feil ved 14.08 minutter for Tidemand-Johannessen , F[rithjof]
#  4829 feil ved 15.94 minutter for Fomitsjenko
#  5924 feil ved 18.44 minutter for Rødsli , Ingegrigt
#  7628 feil ved 23.3 minutter for Seeberg , A[xel] S[egelcke]
#  8329 feil ved 25.88 minutter for Hvidsteen , Chr[istian]
#  8475 feil ved 26.21 minutter for Øyer
#  8562 feil ved 26.41 minutter for Wilhelmsen , Leif J[armann]
#  9040 feil ved 28.5 minutter for B[ing] , M[imi] G[rieg]
#  9075 feil ved 28.57 minutter for Høstmark , [Sverre] Halfdan
# 10000 logg ved 31.67 minutter for ('Berg, Vally', '', '', '', '7001537')
#  10172 feil ved 32.05 minutter for Studio , ImageBooks
#  10434 feil ved 33.65 minutter for Winterstad , M[anfred]
#  10554 feil ved 34.92 minutter for Hambro , C[arl] J[oachim]
#  10666 feil ved 35.17 minutter for Damsleth , H[arald]
#  10760 feil ved 35.38 minutter for Olden , O[le] F[redrik]
#  10887 feil ved 35.67 minutter for Organisering av læringsmiljø
#  12496 feil ved 41.31 minutter for Norges energiverkforbund. Fordelingsnettkomiteen , Arbeidsgruppe 2
#  12817 feil ved 43.04 minutter for Norges Speditørforbund
#  16296 feil ved 56.93 minutter for Mystifax
#  17159 feil ved 59.89 minutter for Kent , [charles
#  17230 feil ved 60.04 minutter for Sagene offentlige lærerskole
#  17580 feil ved 60.84 minutter for Opstad , Steinar
#  18067 feil ved 62.94 minutter for Wang , Erling T[ønder]
#  18609 feil ved 65.19 minutter for Rian , Johan B[ergsveinson]
#  18876 feil ved 66.8 minutter for Hetland , [Audun]
#  18965 feil ved 67.0 minutter for Dehlin , H[arald] Stene
#  19273 feil ved 67.7 minutter for Falck-Andersen , [J.]
# 20000 logg ved 70.37 minutter for ('Iveland, Monica', '', '', '', '97054201')
#  21606 feil ved 75.01 minutter for Z[ernichow] , Sonja
#  21729 feil ved 75.29 minutter for Informasjonsutvalget for Europasaker
#  23491 feil ved 83.33 minutter for Constantin-Weyer , M[aurice]
#  24173 feil ved 84.88 minutter for Fylkeslegen i Vest-Agder
#  26048 feil ved 92.13 minutter for Bloch , A[ndreas]
#  26112 feil ved 92.27 minutter for Stang , Nic[olay]
#  28030 feil ved 97.64 minutter for Wyller , Thomas Chr[istian]
#  28539 feil ved 99.79 minutter for Brûsel & Kjær
# 30000 logg ved 104.11 minutter for ('Fjellanger, Gerd', 'f', '1966', '', '6011816')
#  30041 feil ved 104.2 minutter for Finansdepartementet
#  30888 feil ved 107.12 minutter for Bibelselskapet
#  30955 feil ved 107.27 minutter for [Hav , Fritjof]
#  31171 feil ved 110.76 minutter for Tjernsberg , Torbj[ørn]
#  31279 feil ved 111.0 minutter for Prisdirektoratet
#  31610 feil ved 111.75 minutter for Likestillingsrådet
#  31667 feil ved 111.88 minutter for -d.
#  32232 feil ved 113.16 minutter for Schønning , [Petter] Jonas
#  36515 feil ved 129.89 minutter for Weider , B[jarne] O[dd]
#  39277 feil ved 138.15 minutter for Christiansen , Reidar Th[oralf]
# 40000 logg ved 141.79 minutter for ('La Sale, Antoine de', '', '', '', '90893049')
#  40215 feil ved 142.28 minutter for Tschudi , Aadel [Brun]
#  40340 feil ved 142.56 minutter for Rådet for eldreomsorg
#  41936 feil ved 148.2 minutter for Hanno , O[tto] v[on]
#  42831 feil ved 151.24 minutter for Hardeland , M[agnus]
#  43504 feil ved 152.77 minutter for Lange , Chr[istian] L[ous]
#  44674 feil ved 159.43 minutter for Olafsen , T[ryggve] K[loumann]
#  45726 feil ved 162.85 minutter for [Thrap , Johanne Vilhelmine]
#  46014 feil ved 164.5 minutter for Wangensten-Berge , L[ars]
#  46770 feil ved 166.23 minutter for Mauritz-Hansen , I[var]
#  46891 feil ved 166.51 minutter for Faye-Lund , H[ans]
#  47009 feil ved 166.78 minutter for Østbye , P[eter]
#  47739 feil ved 168.42 minutter for Karmaker , Ratneswar
#  47972 feil ved 168.96 minutter for Ljone , Oddm[und]
#  47979 feil ved 168.97 minutter for [Hellervik , Per]
#  48447 feil ved 170.98 minutter for Wyller , Egil A[nders]
# 50000 logg ved 175.45 minutter for ('Huygen, Wil', '', '', '', '90134888')
#  51102 feil ved 179.96 minutter for Eikrem , P[eder] S[imonsen]
#  51219 feil ved 180.22 minutter for Brambani , A[lfhild]
#  51340 feil ved 180.49 minutter for Jéronaton
#  51687 feil ved 181.29 minutter for Duesund , O[laf]
#  51789 feil ved 181.53 minutter for Hæreid , [Olav]
#  52191 feil ved 182.45 minutter for Stenstadvold , H[åkon]
#  52354 feil ved 182.81 minutter for [Bergesen , Sigval]
#  53862 feil ved 188.22 minutter for Binns , M. R Michael R.)
#  55701 feil ved 194.38 minutter for Grydeland , Hans A[ndreas]
#  55891 feil ved 194.81 minutter for Stiansen , P[eder]
#  56458 feil ved 197.11 minutter for Hjelm-Larsen , H[arald]
#  58331 feil ved 206.39 minutter for Sogn og Fjordane
# 60000 logg ved 213.19 minutter for ('Haug, Tonje', '', '', '', '90743007')
#  60072 feil ved 213.35 minutter for Nissen , Bernt A[ugust]
#  61524 feil ved 220.71 minutter for liebma
#  61996 feil ved 221.77 minutter for Lunden , A[ksel] P[edersen]
#  63084 feil ved 224.23 minutter for Mürer , N[iels] J[ørgen]
#  63370 feil ved 225.89 minutter for Dániel , Gelencsér.
#  63651 feil ved 226.52 minutter for Det Norske Veritas
#  63977 feil ved 227.26 minutter for Elind , G[ondero]
#  64066 feil ved 227.46 minutter for Utne , Fin K[ristian] L[ars]
#  64285 feil ved 227.98 minutter for STYRET FOR VESTFOLD
#  64452 feil ved 228.35 minutter for Gelencsér , Dániel
#  64582 feil ved 228.65 minutter for Tonstad , Serena
#  65900 feil ved 232.68 minutter for Fiangonana Loterana Malagasy
#  66007 feil ved 232.92 minutter for S[axlund] , H[elene]
#  66221 feil ved 235.4 minutter for Reichborn-Kjennerud , I[ngjald]
#  66334 feil ved 235.65 minutter for Bjørge , J[ohan] H[alvor] B[ryn]
#  66424 feil ved 235.86 minutter for Nilsen , Arth[ur] W.
#  66824 feil ved 237.77 minutter for Harsem , P[eter]
#  67346 feil ved 239.95 minutter for Madsen , Øivind
#  67879 feil ved 241.16 minutter for Nordsansjø , Telida
#  68226 feil ved 242.95 minutter for Christensen , Chr[istian] A[rthur] R[ichardt]
#  68510 feil ved 243.6 minutter for Tekstbok til grunnkurs i engelsk for den videregående skolen. - Omarbeidet og utvidet utgave av Cross-Currents 1
#  69146 feil ved 248.05 minutter for Lodgaard , M[agnus]
# 70000 logg ved 250.0 minutter for ('Lancioni, Giulio E.', '', '', '', '90837767')
#  70420 feil ved 250.95 minutter for Den Norske Kreftforening
#  70506 feil ved 252.14 minutter for Lightcon prosjekt
#  71017 feil ved 254.3 minutter for Thorsrud , Jørgen [A.]
#  73336 feil ved 261.56 minutter for Bergen
#  74032 feil ved 263.11 minutter for Borchgrevink , H[ans] Henrik Chr[istian]
#  75346 feil ved 270.1 minutter for Kristiansen , Oddm[und]
#  77224 feil ved 276.41 minutter for Kvellestad , And[ers]
#  77684 feil ved 279.45 minutter for M[hr , Steinar
# 80000 logg ved 288.61 minutter for ('Romstad, Randi', '', '', '', '8046426')
#  83497 feil ved 304.44 minutter for Sputniko!
#  83701 feil ved 304.9 minutter for Sellevoll , Markvard A[rmin]
#  83897 feil ved 306.35 minutter for Lindboe , [Jacob]
#  84228 feil ved 308.11 minutter for Kittelsen , Th[eodor]
#  85664 feil ved 312.39 minutter for Johnson , [Kaare] Espolin
#  85748 feil ved 312.58 minutter for [Premiere: 26. des. 1956]
#  86530 feil ved 316.36 minutter for Hjartøy , H[enrik] J[ohnsen]
#  87327 feil ved 318.13 minutter for Weider , Bjarne O[dd]
#  87959 feil ved 320.58 minutter for [Bovim , Emilie]
#  88301 feil ved 321.36 minutter for Berg , Aug[ust]
#  88583 feil ved 321.98 minutter for E[rstad] , A[ndreas]
#  89246 feil ved 323.49 minutter for Norske Bygder
#  89513 feil ved 324.11 minutter for Arbeidernes ungdomsfylking
#  89776 feil ved 325.71 minutter for Statens Rasjonaliseringsdirektorat
#  89982 feil ved 326.18 minutter for Sprogets venner
# 90000 logg ved 326.22 minutter for ('Bull-Hansen, Bjørn Andreas', 'm', '1972', '', '90945193')
#  90160 feil ved 326.59 minutter for Lied , K. [et al..]
#  90542 feil ved 329.45 minutter for H[ambro] , C[arl] J[oachim]
#  90589 feil ved 329.56 minutter for Drevon , R[obert]
#  90640 feil ved 329.71 minutter for Hammarlund , G[östa]
#  91649 feil ved 332.99 minutter for Kittilsen , Chr[istian]
#  92009 feil ved 333.8 minutter for Segelcke , S[everin]
#  93051 feil ved 337.09 minutter for Tønnessen , Joh[an] N[icolay]
#  93180 feil ved 337.39 minutter for Nilssen , Jens R[ichard]
#  96871 feil ved 350.76 minutter for Norsk Folkemuseum
#  98281 feil ved 354.98 minutter for Røste , B[jørnulf]
#  98916 feil ved 357.43 minutter for Garman , Andreas [Nitter?]
#  99010 feil ved 357.64 minutter for Brinchmann , Alex[ander]
# 100000 logg ved 360.88 minutter for ('Bjelvin, Kjersti', '', '', '', '90764857')
#  102335 feil ved 369.24 minutter for Skapsprengeren Manfreds oppstandelse
#  102871 feil ved 370.46 minutter for Indrebø , R[agnvald]
#  103193 feil ved 372.2 minutter for Johanssen , Joh[an] Th[eodor]
#  105517 feil ved 385.51 minutter for Trondhjems kunstforening
#  106991 feil ved 392.89 minutter for Internasjonal kvinneliga for fred og frihet
#  108318 feil ved 397.92 minutter for Nationaltheatret
#  108803 feil ved 399.03 minutter for -e
# 110000 logg ved 402.77 minutter for ('Bāb, ʿAlī Muḥammad Shīrāzī', '', '', '', '90788522')
#  110253 feil ved 403.35 minutter for Brændeland , D[aniel]
#  110859 feil ved 404.71 minutter for Kapelrud , Arvid S[chou]
#  112403 feil ved 411.22 minutter for Norges fredsråd
#  112413 feil ved 411.24 minutter for Norsk Kartografisk Forening
#  112838 feil ved 413.21 minutter for Engelstad , Carl Fr[edrik]
#  113110 feil ved 414.82 minutter for Stene , Kristi Lunde
#  113350 feil ved 415.36 minutter for Gulbransen , Reidar [I.]
#  114039 feil ved 416.94 minutter for Grundt , M[artha]
#  114700 feil ved 419.45 minutter for Christensen , Chr[istian] A[rthur] R[ichardt
#  114712 feil ved 419.47 minutter for Opinion
#  115620 feil ved 423.58 minutter for Davidsen , Trygve M[arentius]
#  116546 feil ved 429.69 minutter for Høie , Joh[anne]s
#  117022 feil ved 430.77 minutter for Gill , Signe H[irsch]
#  119559 feil ved 440.56 minutter for Charioux , Charioux
# 120000 logg ved 443.56 minutter for ('Kishida, Eriko', '', '', '', '6019960')
#  120433 feil ved 445.54 minutter for Gammelgaard , A[rthur] W.
#  120471 feil ved 445.63 minutter for Tonderum
#  120746 feil ved 446.25 minutter for Suppipat , Nophadol
#  122810 feil ved 452.94 minutter for Bie , Fr[edrik]
#  122860 feil ved 453.05 minutter for Rodin , R[igmor] H.
#  123011 feil ved 453.4 minutter for Frog , [Aksel Bertrand]
#  123976 feil ved 457.58 minutter for Ebbemoe , E.Chr.
#  124033 feil ved 457.71 minutter for Danken
#  124635 feil ved 461.08 minutter for Johannesen , B.Tiedeman[d]
#  126822 feil ved 471.07 minutter for Tschudi , St[ephan]
#  126855 feil ved 472.14 minutter for Trøan , E[yvind]
#  127592 feil ved 475.83 minutter for O[ppegaard] , A. A.
#  128476 feil ved 480.86 minutter for Norges naturvernforbund , Nordsjøutvalget
#  128751 feil ved 482.49 minutter for Berle , Reidar J[ohan]
#  129216 feil ved 483.54 minutter for G[ihbsson] , L[eif]
# 130000 logg ved 487.33 minutter for ('Sandven, Erling', 'm', '1931', '', '90344780')
#  130392 feil ved 489.22 minutter for Alsvik , Hans Chr[istian]
#  130649 feil ved 489.81 minutter for Tinnesand , Edv[in]
#  131957 feil ved 494.8 minutter for Ifea
#  132912 feil ved 497.98 minutter for [Johansen , Conrad]
#  133073 feil ved 499.34 minutter for Thomassen , G[ustav] E.
#  134432 feil ved 503.43 minutter for L[indvig] , E[lisabeth] K[rohn]
#  134880 feil ved 504.44 minutter for Hammarlund , [Gösta]
#  135132 feil ved 505.01 minutter for Buskerud bondekvinnelag
#  136170 feil ved 508.37 minutter for i Følger (verk): Brustad , Victor E.
#  136219 feil ved 508.48 minutter for Thabane , Motlatsi
#  136223 feil ved 508.49 minutter for Fjelstad , Sverre M[artin]
#  137652 feil ved 514.73 minutter for Olden , Ole F[redrik]
#  137747 feil ved 514.95 minutter for Kløvig , Berit [Soot]
#  137770 feil ved 515.0 minutter for DNT Finnskogen og omegn
#  138598 feil ved 517.88 minutter for Barne- , ungdoms- og familiedirektoratet
#  138838 feil ved 518.43 minutter for Friberg , Fred
# 140000 logg ved 523.07 minutter for ('Ross, Colin', '', '', '', '98047672')
#  140831 feil ved 526.96 minutter for Dahl , A[lfred] K.
#  142167 feil ved 532.99 minutter for [Baertling , G.]
#  142361 feil ved 533.43 minutter for Teaterrådet
#  142735 feil ved 534.27 minutter for Findahl , Theo[dor]
#  143378 feil ved 536.72 minutter for Englund , John P[aul]
#  144039 feil ved 539.23 minutter for Kirke- og undervisningskomiteen
#  145766 feil ved 545.16 minutter for Tandberg , H[enry] A[lbert]
#  147489 feil ved 552.04 minutter for Riksantikvaren
#  147762 feil ved 553.67 minutter for Havers , Kitt[y]
#  147869 feil ved 553.91 minutter for Eitrem , S[amson]
#  147896 feil ved 553.97 minutter for Helberg , Leif!
#  147910 feil ved 554.0 minutter for Hanssen , B[rynjolf]
#  148063 feil ved 554.35 minutter for Nesje , Atle
#  149005 feil ved 556.49 minutter for Wisløff , H[ans] E[dvard]
#  149939 feil ved 559.59 minutter for Norge
# 150000 logg ved 559.72 minutter for ('Hope, Ludvig', 'm', '1871', '1954', '90119541')
#  150222 feil ved 560.23 minutter for Meyer , Christopher B[remer] V[ahl]
#  150458 feil ved 560.76 minutter for [Sending , Olav]
#  150545 feil ved 560.95 minutter for Deinboll , Bjørg S[vendsen]
#  151773 feil ved 564.71 minutter for Heltberg , Arnlioth G[elline]
#  152645 feil ved 568.67 minutter for Malterud , O[tto] Chr[istian]
#  153133 feil ved 569.77 minutter for Berle , Reidar [Johan]
#  153906 feil ved 572.52 minutter for Norsk Rikskringkasting. Skoleradioen
#  154014 feil ved 572.76 minutter for Ng~ug~i wa Thing'o
#  154233 feil ved 573.26 minutter for Meiraak , Jahas
#  155614 feil ved 580.4 minutter for Wol[l]ebæk , Per
#  155939 feil ved 581.15 minutter for Sogn og Fjordane teater
#  155999 feil ved 581.28 minutter for Schøyen , T[hor] H[iorth]
#  157340 feil ved 586.32 minutter for Christophersen , R[agnar] I[ngvald]
#  157649 feil ved 587.01 minutter for Brøgger , N[iels] Chr.
# 160000 logg ved 597.38 minutter for ('Willoch, Herman', '', '', '', '2098466')
#  160313 feil ved 599.09 minutter for Bygstad , Joh[anne]s
#  160706 feil ved 601.97 minutter for Marcussen , J[ulius] M[artin]
#  162088 feil ved 608.12 minutter for [Myraker , Leif E.]
#  162832 feil ved 609.79 minutter for Asila
#  163187 feil ved 610.59 minutter for Juristmållaget
#  163943 feil ved 612.33 minutter for Levekårsutvalget
#  163956 feil ved 612.36 minutter for Chiapas
#  165740 feil ved 619.44 minutter for Goderstad , T[orleif]
#  166318 feil ved 621.76 minutter for Knutsen , Chr[istian]
#  166344 feil ved 621.81 minutter for C[lausen] , S[ophus]
#  166880 feil ved 624.04 minutter for Bærum kommune
#  169944 feil ved 634.02 minutter for Rønne-Petersen , E[gil]
# 170000 logg ved 634.15 minutter for ('Charing, Douglas', '', '', '', '98065628')
#  170719 feil ved 637.79 minutter for Helsdirektoratet
#  171146 feil ved 638.75 minutter for Tilrem , [Hans]
#  172209 feil ved 642.18 minutter for Norsk rikskringkasting
#  172278 feil ved 642.34 minutter for Norges Idrettsforbund
#  172665 feil ved 643.23 minutter for Stamsø , T[rond]
#  172734 feil ved 643.39 minutter for Mossige , Sigrid [Munthe]
#  173185 feil ved 645.41 minutter for Wærnes , [Geir]
#  173404 feil ved 645.91 minutter for Johannessen , Jac. [Johan]
#  174650 feil ved 650.73 minutter for Gaskell , [Elizabeth]
#  175084 feil ved 652.73 minutter for Bergens haandværks- og industriforening
#  175513 feil ved 654.71 minutter for Lee , C[harles]
#  175533 feil ved 654.75 minutter for Bakke-Fagerberg , [Sigurd]
#  176466 feil ved 658.86 minutter for [Veum , Torleiv]
#  176592 feil ved 659.14 minutter for Bernhoft-Osa , A[nders]
# 180000 logg ved 671.85 minutter for ('Udaya Sekhar, Nagothu', 'm', '1962', '', '3118376')
#  180714 feil ved 674.45 minutter for Kupe , Tawana
#  182528 feil ved 679.58 minutter for Grimm [Brødrene]
#  182539 feil ved 679.6 minutter for Furuholmen , Gotfr[ed]
#  182598 feil ved 679.73 minutter for Dale , Joh[anne]s A[ndreasson]
#  185631 feil ved 688.58 minutter for Hoffstad , E[inar]
#  186428 feil ved 691.41 minutter for Brøgger , N[iels] Chr[istian]
#  186748 feil ved 692.14 minutter for Norske Arbeiderpartis Stortingsgruppe
#  186997 feil ved 692.7 minutter for Bjerke , Alf E[don]
#  187783 feil ved 695.48 minutter for Derbitchev , Edalguerei
#  188596 feil ved 698.35 minutter for Svensen , Chr[istian]
#  188902 feil ved 699.04 minutter for Løkeland , Bj[arne]
#  188954 feil ved 699.17 minutter for Hurlen , P[eter]
#  189579 feil ved 700.6 minutter for Mürer , Niels J[ørgen]
#  189609 feil ved 700.66 minutter for Jærn , Alb[ert]
# 190000 logg ved 702.56 minutter for ('Sørhus, Lars Voss', 'm', '1974', '', '14046986')
#  191413 feil ved 708.8 minutter for Vestly , Anne-Cath[arina
#  191851 feil ved 710.8 minutter for Helmer , J[an] G[roos]
#  192190 feil ved 712.58 minutter for

# %%
len(names_curated)
# Out:
# 192190
